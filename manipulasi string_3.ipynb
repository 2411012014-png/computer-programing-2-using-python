# %% [markdown]
# Format String

# %%
template = 'Halo, saya %s dari %s'

print(template % ('azzahra zalfa septira', 'Indonesia'))
# Out:
# Halo, saya azzahra zalfa septira dari Indonesia

# %%
template = 'Halo, saya {nama} dari {asal}'
template_2 = 'Saya suka makan {} dan minum {}'

print(template. format (nama = 'azzahra zalfa septira', asal = 'Indonesia') )

print(template_2. format('Nasi Goreng', 'air putih'))
# Out:
# Halo, saya azzahra zalfa septira dari Indonesia
# Saya suka makan Nasi Goreng dan minum air putih

# %% [markdown]
# Sting interpolation

# %%
nama = 'azzahra zalfa septira'
asal = 'Indonesia'
print(f'Perkenalkan saya {nama} dari {asal}😎')
# Out:
# Perkenalkan saya azzahra zalfa septira dari Indonesia😎

# %% [markdown]
# Memecahkan sting menjadi list dan sebaliknya

# %%
alamat = 'Surabaya, Jawa Timur, Indonesia'

print(alamat. split (','))

print(alamat. split())

print(alamat. split(', '))
# Out:
# ['Surabaya', ' Jawa Timur', ' Indonesia']
# ['Surabaya,', 'Jawa', 'Timur,', 'Indonesia']
# ['Surabaya', 'Jawa Timur', 'Indonesia']

# %%
print('❤️'.joni(['aku', 'suka', 'python']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1439/2953346378.py in <cell line: 0>()
# ----> 1 print('❤️'.joni(['aku', 'suka', 'python']))
#
# AttributeError: 'str' object has no attribute 'joni'

# %% [markdown]
# Upper

# %%
print('halo selamat pagi!'.upper())
print('halo selamat siang!'.upper())
# Out:
# HALO SELAMAT PAGI!
# HALO SELAMAT SIANG!

# %% [markdown]
# Lower

# %%
print('APA KABAR?'.lower())
print('LAGI DIMANA!'.lower())
# Out:
# apa kabar?
# lagi dimana!

# %%
print('daun tidak pernah membenci angin'.title())
print('LASKAR PELANGI'.title())
# Out:
# Daun Tidak Pernah Membenci Angin
# Laskar Pelangi

# %%
angka = '12345'
print('indekx angka 3:', angka.find('3'))
print('indekx angka 45:', angka.find('45'))
print('indekx angka 35:', angka.find('35'))
# Out:
# indekx angka 3: 2
# indekx angka 45: 3
# indekx angka 35: -1

# %%
asal = 'lampung'
print(asal.find('p'))
print(asal.find('langu'))
# Out:
# 3
# -1

# %% [markdown]
# MEREPLACE

# %%
ibu_kota = 'jakarta'
print(ibu_kota.replace('a', 'i'))
print(ibu_kota.replace('kar', '🥳'))
# Out:
# jikirti
# ja🥳ta

# %% [markdown]
# Menghapus karakter tertentu pada string

# %%
ibu_kota = 'jakarta'
print(ibu_kota.replace('a', ''))
# Out:
# jkrt

# %%
paragraf = 'Baru-baru ini telah ditemukan sebuah meteor di suatu sungai'
x = paragraf.count('di')

print(f'Kata "di" muncul sebanyak {x} kali')
# Out:
# Kata "di" muncul sebanyak 2 kali

# %% [markdown]
# Menghitung jumlah karakter yg muncul

# %%
paragraf = 'Baru-baru ini telah ditemukan sebuah meteor di suatu sungai'
print(paragraf.count('i'))
# Out:
# 5
